# %%
import pandas as pd
import re


file = pd.read_excel("Прайсы с телеграма 28.01.xlsx")

ALLOWED_RAM_VALUES = {1, 2, 3, 4, 6, 8, 12, 16, 32, 64, 128, 256, 512, 1024}
COLORS_RU_TO_EN = {
    "зелёный": "green",
    "черный": "black",
    "розовое золото": "rose gold",
    "серебро": "silver",
    "коричневый": "brown",
    "голубой": "light blue",
    "розовый": "pink",
    "серый космос": "space gray",
    "желтый": "yellow",
    "сиреневый": "lilac",
    "золотой": "gold",
    "синий": "blue",
    "фиолетовый": "purple",
    "серебристый": "silver",
    "золото": "gold",
    "красный": "red",
    "оранжевый": "orange",
    "темно-синий": "dark blue",
    "зеленый": "green",
    "коралловый": "coral",
    "белый": "white",
    "бежевый": "beige",
    "cерый": "gray",
    "серый": "gray",
}


def get_normalyze_color(color_en, color_ru):
    if pd.isna(color_en) and not pd.isna(color_ru):
        return COLORS_RU_TO_EN[color_ru.lower()]
    return color_en


def get_color(name):
    match = re.search(
        r"\b("
        r"Cyclone Transparent Black|Bright Silver Edition|Awesome Lime Yellow|Seven Degree Purple|Obsidian Midnight|Interstellar Blue|"
        r"Interstellar Grey|Sandstone Orange|Moonlight Silver|Multicolor Green|Mercurial Silver|Natural Titanium|Awesome Graphite|"
        r"Magic Skin Green|Deep Ocean Black|Impression Green|Gradation Purple|Midnight Shadow|Gradient Bronze|Titanium Yellow|"
        r"Celestial Black|Titanium Silver|Moonlight White|Moving Titanium|Startrail Black|Magic Skin Blue|Dreamland Green|Titanium Orange|"
        r"Gradation Black|Platinum Silver|Lavender Purple|Metaverse Green|Gradation Green|Desert Titanium|Awesome Iceblue|Titanium Violet|"
        r"Ice Mirror Blue|Silver Fantasy|Digital Silver|Meteorite Grey|Sparkle Purple|Crystal Silver|Titanium Green|Uranolith Gray|"
        r"Moonlight Blue|Chromatic Gray|Titanium Black|Turquoise Cyan|Metallic Black|Black Titanium|Black Burgundy|Alpenglow Gold|Midnight Black|"
        r"Nighttime Blue|Awesome Silver|Celadon Marble|Glittery White|Obsidian Black|Awesome Violet|Stargase White|Stellar Shadow|Hurricane Blue|"
        r"Sunrise Orange|Ceramics White|White Titanium|Infinite Black|Phantom Silver|Deepsea Luster|Stellar Black|Titanium Gold|Awesome Lilac|"
        r"Titanium Grey|Phantom Black|Dark Illusion|Ceramic White|Graphite Gray|Starry Silver|Glowing Green|Fluorite Blue|Cobalt Violet|Rutile Orange|"
        r"Glacier White|Gravity Black|Crystal Green|Mystery White|Glowing Black|Dreamy Purple|Deep Sea Blue|Basaltic Dark|Cryolite Blue|Atlantic Blue|"
        r"Titanium Gray|Emerald Green|Midnight Gray|Nebula Violet|Flowy Emerald|Dual Jade Fog|Memphis Green|Variable Gold|Daybreak Blue|Silver Shadow|"
        r"Sunset Melody|Stardust Grey|Iceland White|Awesome Black|Twilight Blue|Awesome White|Blue Titanium|Eternal Black|Champion Gold|Crystal Black|"
        r"Sapphire Blue|Seasalt White|Grey Graphite|Obsidian Edge|Starlit Black|Awesome Lemon|Phantom White|Hurrican Blue|Violet Garden|Titanium Blue|"
        r"Awesome Peach|Mecha Silver|Glacier Glow|Diamond Grey|Skyline Blue|Amber Yellow|Mecha Orange|Aurora Green|Mirror Black|Cosmos Black|Frost Silver|"
        r"Crystal Blue|Magma Orange|Thunder Grey|Aurora Cloud|Kyanite Blue|Monet Purple|Forest Green|Awesome Navy|Voyager Grey|Morning Mist|Awesome Blue|"
        r"Horizon Gold|Stormy Black|Snowy Silver|Meteor Black|Starlit Blue|Mighty Black|Frosty Ivory|Light Silver|Polar Silver|Black Aurora|Blossom Glow|"
        r"Magnet Black|Awesome Lime|Pacific Blue|Viva Magenta|Awesome Mint|Cloudy White|Rococo Pearl|Alpine Green|Glacier Blue|Carbon Black|Awesome Gray|"
        r"Starry Black|Glowing Gold|Meadow Green|Ultramarine|Alpine Blue|Polar Black|Prism Black|Wintergreen|Starry Blue|Oasis Green|Kinda Coral|"
        r"Khaki Green|Sunset Gold|Power Black|Comet Green|Clash White|Black Stone|Night Black|Space Black|Pastel Lime|Mars Orange|Sleek Black|Green Field|"
        r"Galaxy Grey|Cross Black|Magic Black|Dark Chrome|Mecha Black|Paper White|Iris Purple|Lemon Green|Marble Gray|Sierra Blue|Rose Quartz|Dark Purple|"
        r"Dark Matter|Deep Purple|Light Green|Sorta Sunny|Dark Welkin|Nebula Blue|Bora Purple|Shadow Grey|Pearl White|Arctic Glow|Desert Sand|Titan Black|"
        r"Lava Orange|Coral Green|Mirror Grey|Bahama Blue|Green Oasis|Speed Green|Speed Black|Mint Green|Rebel Grey|Storm Gray|Light Grey|Ice Silver|"
        r"Speed Blue|Rush Black|Cyber Blue|Misty Aqua|Cross Blue|Light Gray|Snapdragon|Rock Black|Water Gray|Space Grey|Lemongrass|Rome Green|Mist Black|"
        r"Pearl Gold|Onyx Black|Gray Green|Cocoa Gold|Pine Green|Sandy Gold|Blue Oasis|Agua Green|Cloud Mint|Titan Blue|Jade Green|Misty Grey|Blue Black|"
        r"Rangi Blue|Just Black|Navy Black|CobaltBlue|Titan Gray|Mecha Blue|Jewel Blue|Ocean Blue|Amber Gold|Space Gray|Prism Blue|Ocean Teal|Black Onyx|"
        r"Dark Green|Beige Sand|Sage Green|Grey/green|Cloud Navy|Light Blue|Water Blue|Iron Gray|SlateGray|Azure Sky|Sea Green|Lake Blue|Stainless|"
        r"Palm Blue|Star Blue|Aqua Blue|Turquoise|Cool Blue|Dawn Gold|Starlight|Porcelain|Tangerine|Eco Black|Neon Gold|Pink Gold|Deep Grey|Cyan Lake|"
        r"Rose Gold|Jet Black|Dark Blue|Sky Cyan|Icy Blue|Graphite|Burgundy|Platinum|Amethyst|Lavender|Sapphire|Blue Sea|Dark Red|Titanium|Midnight|"
        r"Obsidian|Charcoal|Ice Blue|Sea Blue|Basaltic|Mondrian|Emerald|Iceblue|Natural|Crimson|Silver|Violet|Orange|Indigo|Yellow|Maroon|Copper|Purple|"
        r"Desert|White|Lilac|Brown|Lemon|Peony|Pearl|Black|Hazel|Peach|Coral|Green|Olive|Beige|Azure|Cream|Blue|Cyan|Aloe|Gray|Aqua|Milk|Gold|Grey|Snow|"
        r"Lime|Navy|Teal|Mint|Rose|Pink|Glow|Sea|Bay|Red"
        r")\b",
        name,
        re.IGNORECASE,
    )
    return match.group(0) if match else None


def get_manufacturer(name):
    match = re.search(
        r"\b("
        r"OnePlus|Apple|Samsung|Infinix|Sony|Itel|ZTE|Vivo|Huawei|"
        r"Nothing|Blackview|MOTOROLA|Google|ASUS|Microsoft|"
        r"Oppo|Honor|Poco|Asus|Realme|Tecno|Xiaomi|POCO"
        r")\b",
        name,
        re.IGNORECASE,
    )
    return match.group(0) if match else None


def clean_text(text):
    text = re.sub(r"[^\w\s/.+-]", "", str(text)).strip()
    return text


def get_ram(text):
    match = re.findall(
        r"(\d+)(?:\+|/|\s)(?=\d{1,4}[TtGgBb]|\d{2,4}\b)", text, re.IGNORECASE
    )
    if not match:
        return None
    ram = match[-1]
    return ram if int(ram) in ALLOWED_RAM_VALUES else None


def get_rom(text):
    match = re.search(r"(?:\d+\+)?(32|64|128|256|512|1024)[GgBb ]", text, re.IGNORECASE)
    if match:
        return match.group(1)
    match = re.search(r"(?:\d+\+)?(1|2|3|4)(Tb|TB|T|t)", text, re.IGNORECASE)
    return match.group(1) if match else None


def get_price(text):
    price_matches = re.findall(r"(\b\d{4,6})\s*[₽$€]?", str(text))
    if not price_matches:
        return None
    last_price = int(price_matches[-1])
    return last_price if last_price >= 2025 else None

# %%
def remove_specifications(text, color, ram, rom):
    if color:
        text = text.replace(color, "").strip()

    if ram and rom:
        pattern = rf"{ram}\s*[+/]?\s*{rom}\s*[GgBb]"
        text = re.sub(pattern, "", text, flags=re.IGNORECASE).strip()
    elif ram:
        pattern = rf"{ram}\s*[GgBb]"
        text = re.sub(pattern, "", text, flags=re.IGNORECASE).strip()
    elif rom:
        pattern = rf"{rom}\s*[GgBb]"
        text = re.sub(pattern, "", text, flags=re.IGNORECASE).strip()

    if ram or rom:
        pattern = r"\b[A-Za-z]\b"
        text = re.sub(pattern, "", text).strip()

    text = re.sub(r"\s+", " ", text).strip()

    return text


file.dropna(inplace=True)
MiHonor = file[file["поставщик"] == "MiHonor"].copy()
MiHonor["Цена"] = MiHonor["прайс"].apply(get_price)
MiHonor["price_clean"] = MiHonor["прайс"].apply(
    lambda x: re.sub(r"\s\d+$", "", clean_text(x)).strip()
)
MiHonor["Цвет"] = MiHonor["price_clean"].apply(get_color)
MiHonor["RAM"] = MiHonor["price_clean"].apply(get_ram)
MiHonor["ROM"] = MiHonor["price_clean"].apply(get_rom)
MiHonor["Наименование товара"] = MiHonor.apply(
    lambda row: remove_specifications(
        row["price_clean"], row["Цвет"], row["RAM"], row["ROM"]
    ),
    axis=1,
)
col = MiHonor.pop("Наименование товара")
MiHonor.insert(1, "Наименование товара", col)

MiHonor = MiHonor[MiHonor["price_clean"].str.strip() != ""]
MiHonor = MiHonor.dropna(subset=["Цена", "Цвет"], how="all")
MiHonor = MiHonor.dropna(subset=["Цвет", "RAM", "ROM"], how="all")

# %%
def clean_text_price(text):
    text = re.sub(r"[^\w\s/.+-]", "", text).strip()
    return re.sub(r"\s\d+$", "", text).strip()


def clean_text_final(text, color, rom):
    if rom:
        text = text.replace(rom, "").strip()
    if color:
        text = text.replace(color, "").strip()
    text = re.sub(r"\b(?:GB|TB|T|G)\b(?!\d)", "", text, flags=re.IGNORECASE).strip()
    return text


file.dropna(inplace=True)
Hi = file[file["поставщик"] == "HI"].copy()
Hi["price_clean"] = Hi["прайс"].apply(clean_text)
Hi["Цена"] = Hi["price_clean"].apply(get_price)
Hi["ROM"] = Hi["price_clean"].apply(get_rom)
Hi["Наименование товара"] = Hi["price_clean"].apply(clean_text_price)
Hi["Цвет"] = Hi["Наименование товара"].apply(get_color)
Hi["Наименование товара"] = Hi.apply(
    lambda row: clean_text_final(row["Наименование товара"], row["Цвет"], row["ROM"]),
    axis=1,
)

Hi = Hi[Hi["price_clean"].str.strip() != ""]
Hi = Hi.dropna(subset=["Цена"], how="all")

# %%
def remove_specifications(text, color, ram, rom):
    if color:
        text = text.replace(color, "").strip()

    if rom:
        text = re.sub(rom, "", text, flags=re.IGNORECASE).strip()
    if ram:
        text = re.sub(rf"(?:({ram}/))", "", text, flags=re.IGNORECASE).strip()

    text = re.sub(r"\s+", " ", text).strip()

    text = re.sub(r"\b(?:GB|TB|T|G)\b(?!\d)", "", text, flags=re.IGNORECASE).strip()

    return text


file.dropna(inplace=True)
YouTakeAll = file[file["поставщик"] == "YouTakeAll"].copy()
YouTakeAll["Цена"] = YouTakeAll["прайс"].apply(get_price)
YouTakeAll["price_clean"] = YouTakeAll["прайс"].apply(
    lambda x: re.sub(
        r"\s\d+$", "", clean_text(re.sub(r"[а-яА-ЯёЁ]", "", x).strip())
    ).strip()
)
YouTakeAll["RAM"] = YouTakeAll["price_clean"].apply(get_ram)
YouTakeAll["ROM"] = YouTakeAll["price_clean"].apply(get_rom)
YouTakeAll["Цвет"] = YouTakeAll["price_clean"].apply(get_color)

YouTakeAll["Наименование товара"] = YouTakeAll.apply(
    lambda row: remove_specifications(
        row["price_clean"], row["Цвет"], row["RAM"], row["ROM"]
    ),
    axis=1,
)
col = YouTakeAll.pop("Наименование товара")
YouTakeAll.insert(1, "Наименование товара", col)

YouTakeAll = YouTakeAll.dropna(subset=["Цена", "RAM", "ROM", "Цвет"], how="all")

# %%
def remove_specifications(text, color, ram, rom, price):
    if price and pd.notna(price):
        text = text.replace(str(int(price)), "").strip()

    if color:
        text = text.replace(color, "").strip()

    if rom:
        text = re.sub(rom, "", text, flags=re.IGNORECASE).strip()
    if ram:
        text = re.sub(rf"(?:({ram}/))", "", text, flags=re.IGNORECASE).strip()

    text = re.sub(r"\s+", " ", text).strip()

    text = re.sub(r"\b(?:GB|TB|T|G)\b(?!\d)", "", text, flags=re.IGNORECASE).strip()

    text = re.sub(r"[\-.]$", "", text).strip()

    return text


file.dropna(inplace=True)
pav112 = file[file["поставщик"] == "112пав"].copy()
pav112["price_clean"] = pav112["прайс"].apply(lambda x: re.sub(r"\.$", "", clean_text(x)))
pav112["Цена"] = pav112["price_clean"].apply(get_price)
pav112["RAM"] = pav112["price_clean"].apply(get_ram)
pav112["ROM"] = pav112["price_clean"].apply(get_rom)
pav112["Цвет"] = pav112["price_clean"].apply(get_color)
pav112["Наименование товара"] = pav112.apply(
    lambda row: remove_specifications(
        row["price_clean"], row["Цвет"], row["RAM"], row["ROM"], row["Цена"]
    ),
    axis=1,
)
col = pav112.pop("Наименование товара")
pav112.insert(1, "Наименование товара", col)
pav112 = pav112.dropna(subset=["Цена", "RAM", "ROM", "Цвет"], how="all")

# %%
all_data = pd.concat([MiHonor, Hi, YouTakeAll, pav112], ignore_index=True)
all_data["RAM"] = all_data["RAM"].astype("Int64")


def standardize_memory(value):
    if pd.isna(value):
        return None
    if value == "1":
        value = "1024"
    return f"{value}GB"


all_data["ROM"] = all_data["ROM"].apply(standardize_memory)


def make_comparison(row):
    name = row.get("Наименование товара")
    ram = row.get("RAM")
    rom = row.get("ROM")
    color = row.get("Цвет")

    is_ram_na = pd.isna(ram)
    is_rom_na = pd.isna(rom)
    is_color_na = pd.isna(color)

    if not name:
        return None

    if not is_color_na:
        color = " ".join(word.capitalize() for word in str(color).split())

    if is_ram_na and not is_rom_na and not is_color_na:
        return f"{name} {rom} ({color})"

    if is_color_na and not is_ram_na and not is_rom_na:
        return f"{name} {ram}/{rom}"

    if is_ram_na and is_color_na and not is_rom_na:
        return f"{name} {rom}"

    if is_ram_na and is_color_na and is_rom_na:
        return name

    if is_ram_na and not is_color_na and is_rom_na:
        return f"{name} ({color})"

    return f"{name} {ram}/{rom} ({color})"


all_data["Сопоставление"] = all_data.apply(make_comparison, axis=1)
col = all_data.pop("Сопоставление")
all_data.insert(1, "Сопоставление", col)

all_data["Производитель"] = all_data["Наименование товара"].apply(get_manufacturer)

all_data["Цвет"] = all_data["Цвет"].apply(lambda x: x.lower() if x else None)

df_shop = pd.read_excel("Товары магазина.xlsx")

memory_mapping = {
    "1024GB": ["1TB", "1ТБ"],
    "2048GB": ["2TB", "2ТБ"],
}


def standardize_memory(value, name):
    if pd.isna(value):
        rom = get_rom(name)
        return "1024GB" if rom == "1" else f"{rom}GB"

    for standard, variants in memory_mapping.items():
        if str(value) in variants:
            return standard
    return value


df_shop["Встроенная память"] = df_shop.apply(
    lambda row: standardize_memory(row["Встроенная память"], row["Наименование"]),
    axis=1,
)


col = df_shop["Наименование"].apply(get_color)
df_shop.insert(1, "Color", col)
df_shop["Color"] = df_shop["Color"].apply(lambda x: x.lower() if x else None)


df_shop["Color"] = df_shop.apply(
    lambda row: get_normalyze_color(
        color_en=row["Color"],
        color_ru=row["Цвет"],
    ),
    axis=1,
)


def get_normalyze(text, color_en, ram, rom, type_=None):
    if pd.isna(text):
        return text
    if type_:
        text = text.replace(str(type_), "").strip()
    if pd.isna(ram):
        text += f" | color: {color_en}, ram: {ram}, rom: {rom}"
    else:
        text += f" | color: {color_en}, ram: {int(ram)}, rom: {rom}"
    return re.sub(r"\s+", " ", str(text).strip().lower())


df_shop["Сопоставление"] = df_shop.apply(
    lambda row: get_normalyze(
        text=row["Наименование"],
        type_=row["Тип аппарата"],
        color_en=row["Color"],
        ram=row["Оперативная память (Gb)"],
        rom=row["Встроенная память"],
    ),
    axis=1,
)

all_data["Сопоставление"] = all_data.apply(
    lambda row: get_normalyze(
        text=row["Сопоставление"], color_en=row["Цвет"], ram=row["RAM"], rom=row["ROM"]
    ),
    axis=1,
)

# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer


model = SentenceTransformer("fine_tuned_mpnet_v3")

new_df = pd.DataFrame(columns=["Товар поставщика", "Товар в магазине"])

SIMILARITY = 0.9

print("[WAITING] Происходит загрузка модели")
embeddings = model.encode(df_shop["Сопоставление"].tolist(), normalize_embeddings=True)
print("[MODEL DOWNLOAD]")

for index, row in all_data.iterrows():
    if pd.notna(row["Сопоставление"]):
        query_embedding = model.encode(
            [row["Сопоставление"]], normalize_embeddings=True
        )
        scores = np.dot(embeddings, query_embedding.T).flatten()

        best_match_ind = np.argmax(scores)
        best_match_score = scores[best_match_ind]

        if best_match_score >= SIMILARITY:
            best_match = df_shop.iloc[best_match_ind]["Наименование"]
            foreign_key = df_shop.iloc[best_match_ind]["Внешний код"]

            new_row = {
                "Внешний код": foreign_key,
                "Товар в магазине": best_match,
                "Поставщик": row["поставщик"],
                "Цена": row["Цена"],
                "Товар поставщика": row["прайс"],
                "Сходство": best_match_score,
            }
            new_df = pd.concat([new_df, pd.DataFrame([new_row])], ignore_index=True)

    print(f"[{index + 1}/{len(all_data)}] - Обработка товара: {row['прайс']}")
# Out:
# [WAITING] Происходит загрузка модели
# [MODEL DOWNLOAD]
# [1/656] - Обработка товара: 🇪🇺REDMI PAD SE 8.7 WI-FI 6+128GB GREEN 13000₽
# [2/656] - Обработка товара: 🇪🇺REDMI PAD SE 8.7 WI-FI 6+128GB BLUE 13000₽
# [3/656] - Обработка товара: 🇬🇧REDMI PAD SE 8.7 WI-FI 6+128GB GRAY 13000₽5
# [4/656] - Обработка товара: 🇨🇳SAMSUNG TAB A9 SM-X110 4+64GB SILVER 10600₽
# [5/656] - Обработка товара: 🇨🇳SAMSUNG TAB A9 SM-X110 4+64GB GRAPHITE 10600₽
# [6/656] - Обработка товара: 🇨🇳SAMSUNG TAB A9 SM-X110 4+64GB NAVY 10600₽
# [7/656] - Обработка товара: 🇨🇳SAMSUNG TAB A9 SM-X110 8+128GB SILVER 12900₽
# [8/656] - Обработка товара: 🇨🇳SAMSUNG TAB A9 SM-X110 8+128GB NAVY 12900₽
# [9/656] - Обработка товара: 🇨🇳SAMSUNG TAB A9 SM-X110 8+128GB GRAPHITE 12900₽
# [10/656] - Обработка товара: 🇨🇳SAMSUNG TAB A9 SM-X115 8+128GB SILVER 15900₽
# [11/656] - Обработка товара: 🇨🇳SAMSUNG TAB A9 SM-X115 8+128GB NAVY 15900₽
# [12/656] - Обработка товара: 🇨🇳SAMSUNG TAB A9 SM-X115 8+128GB GRAPHITE 15900₽
# [13/656] - Обработка товара: 🇨🇳SAMSUNG A9 PLUS SM-X210 8+128GB NAVY 20500₽
# [14/656] - Обработка товара: 🇨🇳SAMSUNG A9 PLUS SM-X210 8+128GB GRAPHITE 20500₽
# [15/656] - Обработка товара: 🇨🇳SAMSUNG A9 PLUS SM-X210 8+128GB SILVER 20500₽
# [16/656] - Обработка товара: 🇨🇳SAMSUNG A9 PLUS 5G SM-X216B 8+128GB NAVY 22000₽8
# [17/656] - Обработка товара: 🇨🇳SAMSUNG A9 PLUS 5G SM-X216B 8+128GB GRAPHITE 22000₽4
# [18/656] - Обработка товара: 🇨🇳SAMSUNG A9 PLUS 5G SM-X216B 8+128GB SILVER 22000₽9
# [19/656] - Обработка товара: 🇯🇵GOOGLE PIXEL 7A 128GB SEA 29900₽2
# [20/656] - Обработка товара: 🇺🇸GOOGLE PIXEL 7 PRO 128GB SNOW US 40200₽9
# [21/656] - Обработка товара: 🇺🇸GOOGLE PIXEL 7 PRO 128GB OBSIDIAN US 40200₽8
# [22/656] - Обработка товара: 🇺🇸GOOGLE PIXEL 7 PRO 128GB HAZEL US 40200₽
# [23/656] - Обработка товара: 🇺🇸GOOGLE PIXEL 7 PRO 256GB OBSIDIAN US  42700₽5
# [24/656] - Обработка товара: 🇺🇸GOOGLE PIXEL 7 PRO 256GB SNOW US 42700₽8
# [25/656] - Обработка товара: 🇨🇦Google Pixel 9 12/256Gb Porcelain  70000₽4
# [26/656] - Обработка товара: 🇺🇸Google Pixel 9 12/256Gb Obsidian 70000₽4
# [27/656] - Обработка товара: 🇺🇸Google Pixel 9 12/256Gb Peony 70000₽2
# [28/656] - Обработка товара: 🇺🇸Google Pixel 9 12/256Gb Porcelain 70000₽2
# [29/656] - Обработка товара: 🇨🇦Google Pixel 9 PRO 16/128Gb Porcelain 78000₽7
# [30/656] - Обработка товара: 🇨🇦Google Pixel 9 PRO 16/128Gb OBSIDIAN 78000₽3
# [31/656] - Обработка товара: 🇯🇵Google Pixel 9 PRO 16/256Gb Hazel 97000₽7
# [32/656] - Обработка товара: Obsidian 97000₽5
# [33/656] - Обработка товара: Rose Quartz 97000₽6
# [34/656] - Обработка товара: Rose Quartz 97000₽2
# [35/656] - Обработка товара: 🇺🇸GOOGLE PIXEL 9 PRO XL 128GB OBSIDDIAN 84500₽
# [36/656] - Обработка товара: 🇷🇺INOI A72 4G 4+128GB PURPLE 5640₽
# [37/656] - Обработка товара: 🇷🇺INOI A72 4G 4+128GB GRAY 5640₽8
# [38/656] - Обработка товара: 🇮🇳SAMSUNG F15 4+128GB GREEN 14000₽
# [39/656] - Обработка товара: 🇮🇳SAMSUNG F15 4+128GB PURPLE 14000₽
# [40/656] - Обработка товара: 🇮🇳SAMSUNG F15 4+128GB BLACK 14000₽
# [41/656] - Обработка товара: 🇮🇳SAMSUNG M35 6+128GB DARK BLUE  17800₽
# [42/656] - Обработка товара: 🇮🇳SAMSUNG M35 6+128GB BLUE 17800₽
# [43/656] - Обработка товара: 🇮🇳SAMSUNG M35 6+128GB GRAY 17800₽
# [44/656] - Обработка товара: 🇮🇳SAMSUNG M55 5G 8+256GB GREEN 28000₽9
# [45/656] - Обработка товара: 🇮🇳SAMSUNG M55S 5G 8+128GB BLACK 23500₽
# [46/656] - Обработка товара: 🇮🇳SAMSUNG M55S 5G 8+128GB GREEN 23500₽
# [47/656] - Обработка товара: 🇮🇳SAMSUNG M55S 5G 8+256GB BLACK 28500₽
# [48/656] - Обработка товара: 🇮🇳SAMSUNG M55S 5G 8+256GB GREEN 28500₽
# [49/656] - Обработка товара: 🇮🇳SAMSUNG F55 8+256GB BLACK  25500₽
# [50/656] - Обработка товара: 🇮🇳SAMSUNG F55 8+256GB ORANGE  25500₽1
# [51/656] - Обработка товара: 🇨🇳SAMSUNG A06 6+128GB LIGHT BLUE 11000₽
# [52/656] - Обработка товара: 🇨🇳SAMSUNG A06 6+128GB GOLD 11000₽
# [53/656] - Обработка товара: 🇻🇳SAMSUNG A15 4+128GB YELLOW 13850₽
# [54/656] - Обработка товара: 🇻🇳SAMSUNG A15 6 128GB BLUE 14200₽
# [55/656] - Обработка товара: 🇻🇳SAMSUNG A15 6 128GB BLACK 14200₽
# [56/656] - Обработка товара: 🇻🇳SAMSUNG A15 6 128GB YELLOW  14200₽
# [57/656] - Обработка товара: 🇲🇾SAMSUNG A15 8 256GB YELLOW 16500₽
# [58/656] - Обработка товара: 🇻🇳SAMSUNG A16 4 128GB BLACK  13000₽
# [59/656] - Обработка товара: 🇻🇳SAMSUNG A16 4 128GB GRAY  13000₽
# [60/656] - Обработка товара: 🇻🇳SAMSUNG A16 4 128GB GREEN 13000₽
# [61/656] - Обработка товара: 🇻🇳SAMSUNG A16 6 128GB GREEN 14800₽
# [62/656] - Обработка товара: 🇻🇳SAMSUNG A16 8 256GB GREEN 16800₽
# [63/656] - Обработка товара: 🇻🇳SAMSUNG A16 8 256GB GRAY 16900₽
# [64/656] - Обработка товара: 🇻🇳SAMSUNG A16 8 256GB BLACK 16600₽
# [65/656] - Обработка товара: 🇰🇿SAMSUNG A16 8 256GB GRAY 16800₽
# [66/656] - Обработка товара: 🇮🇳SAMSUNG A25 6 128 LIGHT BLUE  17700₽
# [67/656] - Обработка товара: 🇻🇳SAMSUNG A25 6 128 LIGHT BLUE 17700₽
# [68/656] - Обработка товара: 🇮🇳SAMSUNG A25 8 256 LIGHT BLUE 20700₽
# [69/656] - Обработка товара: 🇮🇳SAMSUNG A25 8 256 BLACK 20700₽
# [70/656] - Обработка товара: 🇻🇳SAMSUNG A35 8 256GB LEMON 24200₽
# [71/656] - Обработка товара: 🇻🇳SAMSUNG A55 8+128GB YELLOW 28100₽
# [72/656] - Обработка товара: 🇻🇳SAMSUNG A55 8 128GB BLACK 28100₽
# [73/656] - Обработка товара: 🇻🇳SAMSUNG A55 8 128GB LEMON 28100₽
# [74/656] - Обработка товара: 🇮🇳SAMSUNG A55 12+256GB BLUE 31900₽
# [75/656] - Обработка товара: 🇮🇳SAMSUNG A55 12+256GB LILAC 31400₽
# [76/656] - Обработка товара: 🇻🇳SAMSUNG S21 FE 5G 8+128GB OLIVE 25800₽1
# [77/656] - Обработка товара: 🇮🇳SAMSUNG S23 FE 8+128GB GRAPHITE 34000₽
# [78/656] - Обработка товара: 🇮🇳SAMSUNG S23 FE 8+128GB MINT 34000₽
# [79/656] - Обработка товара: 🇻🇳SAMSUNG S23 ULTRA 12+256GB BLACK 67500₽
# [80/656] - Обработка товара: 🇻🇳SAMSUNG S24 FE 8+512GB GRAY 55900₽
# [81/656] - Обработка товара: 🇻🇳SAMSUNG S24 FE 8+512GB BLUE 55900₽
# [82/656] - Обработка товара: 🇻🇳SAMSUNG S24 FE 8+512GB GRAPHITE 55900₽
# [83/656] - Обработка товара: 🇻🇳SAMSUNG S24 8+128GB GRAY 53500₽7
# [84/656] - Обработка товара: 🇻🇳SAMSUNG S24 PLUS 12+256GB BLACK 69000₽2
# [85/656] - Обработка товара: 🇻🇳SAMSUNG S24 PLUS 12+256GB YELLOW 69000₽
# [86/656] - Обработка товара: 🇻🇳SAMSUNG S24 ULTRA 12+256GB GRAY 80500₽
# [87/656] - Обработка товара: 🇻🇳SAMSUNG S24 ULTRA 12+256GB YELLOW 80500₽5
# [88/656] - Обработка товара: 🇻🇳SAMSUNG S24 ULTRA 12+256GB BLACK  80500₽
# [89/656] - Обработка товара: 🇻🇳SAMSUNG S24 ULTRA 12+512GB BLACK 93500₽
# [90/656] - Обработка товара: 🇻🇳SAMSUNG S24 ULTRA 12+512GB GRAY 93300₽
# [91/656] - Обработка товара: 🇻🇳SAMSUNG S24 ULTRA 12+512GB VIOLET 93300₽
# [92/656] - Обработка товара: 🇷🇺REDMI A3X 3+64GB WHITE 5000₽
# [93/656] - Обработка товара: 🇷🇺REDMI A3 4+128GB BLUE 6000₽
# [94/656] - Обработка товара: 🇷🇺REDMI 12 8+256GB BLUE 10100₽
# [95/656] - Обработка товара: 🇷🇺REDMI 13 6+128GB GOLD 10200₽
# [96/656] - Обработка товара: 🇷🇺REDMI 14C 4+128GB BLUE 8700₽
# [97/656] - Обработка товара: 🇷🇺REDMI 14C 4+128GB GREEN 8700₽
# [98/656] - Обработка товара: 🇷🇺REDMI 14C 8+256GB BLACK 10300₽
# [99/656] - Обработка товара: 🇷🇺REDMI 14C 8+256GB BLUE 10300₽
# [100/656] - Обработка товара: 🇷🇺REDMI 14C 8+256GB GREEN 10300₽
# [101/656] - Обработка товара: 🇷🇺MI 12 LITE 8+128GB PINK  15700₽
# [102/656] - Обработка товара: 🇷🇺NOTE 14 8+128GB OCEAN BLUE 16700₽
# [103/656] - Обработка товара: 🇷🇺NOTE 14 8+128GB LIME GREEN 16700₽
# [104/656] - Обработка товара: 🇷🇺NOTE 14 8+256GB OCEAN BLUE 17700₽6
# [105/656] - Обработка товара: 🇷🇺NOTE 14 8+256GB LIME GREEN 17700₽
# [106/656] - Обработка товара: 🇪🇺NOTE 14 PRO 8+256GB PURPLE 25500₽
# [107/656] - Обработка товара: 🇷🇺NOTE 14 PRO 8+256GB BLACK 25500₽
# [108/656] - Обработка товара: 🇷🇺NOTE 14 PRO 8+256GB OCEAN BLUE 25500₽4
# [109/656] - Обработка товара: 🇷🇺NOTE 14 PRO 12+256GB PURPLE 28900₽
# [110/656] - Обработка товара: 🇷🇺NOTE 14 PRO 12+512GB BLACK 29900₽
# [111/656] - Обработка товара: 🇷🇺NOTE 14 PRO 12+512GB OCEAN BLUE 29900₽
# [112/656] - Обработка товара: 🇷🇺NOTE 14 PRO 12+512GB PURPLE 29900₽
# [113/656] - Обработка товара: 🇪🇺NOTE 14 PRO + 5G 8+256GB BLACK 35000₽
# [114/656] - Обработка товара: 🇪🇺NOTE 14 PRO + 5G 8+256GB BLUE 35000₽
# [115/656] - Обработка товара: 🇪🇺NOTE 14 PRO + 5G 8+256GB PURPLE 35000₽
# [116/656] - Обработка товара: 🇷🇺NOTE 14 PRO + 5G 8+256GB BLUE 37200₽
# [117/656] - Обработка товара: 🇷🇺NOTE 14 PRO + 5G 8+256GB BLACK 37200₽
# [118/656] - Обработка товара: 🇪🇺NOTE 14 PRO + 5G 12+512GB BLACK 39300₽8
# [119/656] - Обработка товара: 🇪🇺NOTE 14 PRO + 5G 12+512GB PURPLE 39300₽
# [120/656] - Обработка товара: 🇪🇺NOTE 14 PRO + 5G 12+512GB BLUE 39300₽
# [121/656] - Обработка товара: 🇷🇺NOTE 14 PRO + 5G 12+512GB BLUE 40000₽
# [122/656] - Обработка товара: 🇷🇺NOTE 14 PRO + 5G 12+512GB BLACK 40000₽
# [123/656] - Обработка товара: 🇪🇺NOTE 13 PRO 8 256GB BLACK 21100₽
# [124/656] - Обработка товара: 🇪🇺NOTE 13 PRO 8 256GB PURPLE 21100₽
# [125/656] - Обработка товара: 🇷🇺NOTE 13 PRO 5G 8+256GB BLUE 25800₽3
# [126/656] - Обработка товара: 🇪🇺NOTE 13 PRO 4G 12+512GB BLACK 25500₽
# [127/656] - Обработка товара: 🇪🇺NOTE 13 PRO 4G 12+512GB GREEN 25500₽
# [128/656] - Обработка товара: 🇪🇺NOTE 13 PRO 4G 12+512GB PURPLE 25500₽
# [129/656] - Обработка товара: 🇷🇺NOTE 13 PRO 5G 12+512 BLACK 29900₽
# [130/656] - Обработка товара: 🇷🇺NOTE 13 PRO 5G 12+512 BLUE 29900₽
# [131/656] - Обработка товара: 🇬🇧NOTE 13 PRO 5G 12+512GB PURPLE 28700₽
# [132/656] - Обработка товара: 🇬🇧NOTE 13 PRO 5G 12+512GB BLACK 28700₽
# [133/656] - Обработка товара: 🇬🇧NOTE 13 PRO 5G 12+512GB TEAL 28700₽
# [134/656] - Обработка товара: 🇪🇺NOTE 13 PRO 5G 12+512GB TEAL 28700₽
# [135/656] - Обработка товара: 🇪🇺NOTE 13 PRO 5G 12+512GB PURPLE 28700₽7
# [136/656] - Обработка товара: 🇪🇺NOTE 13 PRO + 8+256 5G BLACK 28900₽7
# [137/656] - Обработка товара: 🇪🇺NOTE 13 PRO + 8+256GB 5G PURPLE 28900₽
# [138/656] - Обработка товара: 🇪🇺NOTE 13 PRO + 8+256 5G WHITE 28900₽
# [139/656] - Обработка товара: 🇪🇺NOTE 13 PRO + 12+512 5G BLACK 35000₽
# [140/656] - Обработка товара: 🇪🇺NOTE 13 PRO + 12+512 5G PURPLE 35000₽
# [141/656] - Обработка товара: 🇪🇺NOTE 13 PRO + 12+512 5G WHITE 35000₽
# [142/656] - Обработка товара: 🇬🇧NOTE 13 PRO + 12+ 512 5G WHITE 34900₽
# [143/656] - Обработка товара: 🇪🇺MI 13T 12+256GB BLUE 34500₽
# [144/656] - Обработка товара: 🇬🇧MI 13T 12+256GB GREEN 34500₽6
# [145/656] - Обработка товара: 🇪🇺MI 13T PRO 12+256B BLACK 44500₽9
# [146/656] - Обработка товара: 🇬🇧MI 13T PRO 12+512GB BLACK 47300₽
# [147/656] - Обработка товара: 🇬🇧MI 13T PRO 12+512GB GREEN 47300₽
# [148/656] - Обработка товара: 🇪🇺MI 13T PRO 12+512GB BLACK 47400₽
# [149/656] - Обработка товара: 🇪🇺MI 13T PRO 12+512GB BLUE 47400₽
# [150/656] - Обработка товара: 🇪🇺MI 13T PRO 12+512GB GREEN 47400₽
# [151/656] - Обработка товара: 🇪🇺MI 13T PRO 16+1024GB BLACK 49400₽
# [152/656] - Обработка товара: 🇪🇺MI 13T PRO 16+1024GB BLUE 49400₽
# [153/656] - Обработка товара: 🇪🇺MI 13T PRO 16+1024GB GREEN 49400₽
# [154/656] - Обработка товара: 🇺🇸MI 14T 5G 12+256GB BLUE 38000₽
# [155/656] - Обработка товара: 🇪🇺MI 14T 5G 12+256GB BLACK  38300₽
# [156/656] - Обработка товара: 🇪🇺MI 14T 5G 12+256GB BLUE 38300₽
# [157/656] - Обработка товара: 🇪🇺MI 14T 5G 12+256GB GREEN 38300₽
# [158/656] - Обработка товара: 🇪🇺MI 14T 5G 12+512GB BLACK  41500₽
# [159/656] - Обработка товара: 🇪🇺MI 14T 5G 12+512GB GRAY  41500₽
# [160/656] - Обработка товара: 🇪🇺MI 14T 5G 12+512GB GREEN  41500₽
# [161/656] - Обработка товара: 🇷🇺MI 14T PRO 12+256GB BLACK 53800₽
# [162/656] - Обработка товара: 🇷🇺MI 14T PRO 12+256GB GREY 53800₽4
# [163/656] - Обработка товара: 🇷🇺MI 14T PRO 12+256GB BLUE 53800₽74
# [164/656] - Обработка товара: 🇬🇧MI 14T PRO 5G 12+512GB GRAY 55500₽
# [165/656] - Обработка товара: 🇬🇧MI 14T PRO 5G 12+512GB BLACK 55500₽
# [166/656] - Обработка товара: 🇪🇺MI 14T PRO 5G 12+512GB BLACK 56500₽
# [167/656] - Обработка товара: 🇪🇺MI 14T PRO 5G 12+512GB BLUE 56500₽
# [168/656] - Обработка товара: 🇪🇺MI 14T PRO 5G 12+512GB GRAY 56500₽
# [169/656] - Обработка товара: 🇬🇧MI 14T PRO 5G 12+1024GB BLACK 61500₽
# [170/656] - Обработка товара: 🇬🇧MI 14T PRO 5G 12+1024GB BLUE 61500₽7
# [171/656] - Обработка товара: 🇬🇧MI 14T PRO 5G 12+1024GB GRAY 61500₽
# [172/656] - Обработка товара: 🇪🇺MI 14T PRO 5G 12+1024GB BLUE 62700₽
# [173/656] - Обработка товара: 🇪🇺MI 14T PRO 5G 12+1024GB GRAY 62700₽
# [174/656] - Обработка товара: 🇷🇺POCO C61 4+128GB GREEN 6450₽
# [175/656] - Обработка товара: 🇷🇺POCO C61 4+128GB WHITE 6450₽
# [176/656] - Обработка товара: 🇷🇺POCO C61 4+128 BLACK 6450₽6
# [177/656] - Обработка товара: 🇪🇺POCO M6 PRO 12+512GB BLACK 20450₽
# [178/656] - Обработка товара: 🇪🇺POCO M6 PRO 12+512GB BLUE 20450₽
# [179/656] - Обработка товара: 🇪🇺POCO M6 PRO 12+512GB PURPLE 20450₽
# [180/656] - Обработка товара: 🇪🇺POCO F6 8 256GB BLACK 31800₽
# [181/656] - Обработка товара: 🇪🇺POCO F6 8 256GB GREEN 31800₽2
# [182/656] - Обработка товара: 🇪🇺POCO F6 PRO 12+512GB WHITE 44400₽
# [183/656] - Обработка товара: 🇪🇺POCO F6 PRO 12+512GB BLACK 44300₽
# [184/656] - Обработка товара: 🇪🇺POCO X7 12+512GB GREEN 29500₽
# [185/656] - Обработка товара: 🇪🇺POCO X7 12+512GB BLACK 29500₽
# [186/656] - Обработка товара: 🇪🇺POCO X7 12+512GB SILVER 29500₽
# [187/656] - Обработка товара: 🇪🇺POCO X7 PRO 12+512GB YELLOW 36500₽
# [188/656] - Обработка товара: 🇪🇺POCO X7 PRO 12+512GB GREEN 36500₽
# [189/656] - Обработка товара: 🇪🇺POCO X7 PRO 12+512GB BLACK 36500₽1
# [190/656] - Обработка товара: 🇷🇺TECNO SPARK GO1 4+64GB BLACK 6100₽
# [191/656] - Обработка товара: 🇷🇺TECNO SPARK 30 8+128GB BLACK 10200₽
# [192/656] - Обработка товара: 🇷🇺TECNO SPARK 30 8+256GB BLACK 11200₽
# [193/656] - Обработка товара: 🇷🇺TECNO SPARK 30C 4+128GB BLACK 9200₽
# [194/656] - Обработка товара: 🇷🇺TECNO SPARK 30C 4+128GB WHITE 9200₽
# [195/656] - Обработка товара: 🇷🇺TECNO SPARK 30 PRO 8+128GB BLACK 13200₽8
# [196/656] - Обработка товара: 🇷🇺TECNO SPARK 30 PRO 8+128GB WHITE 13200₽
# [197/656] - Обработка товара: 🇷🇺TECNO CAMON 30S 8+128GB BLACK 13500₽
# [198/656] - Обработка товара: 🇷🇺HONOR X6b 4+128GB GREEN 9600₽
# [199/656] - Обработка товара: 🇷🇺HONOR X6b 4+128GB BLACK 9600₽
# [200/656] - Обработка товара: 🇷🇺HONOR X6b 6 256GB GREEN 10500₽
# [201/656] - Обработка товара: 🇷🇺HONOR X7C 6+128GB BLACK 11500₽6
# [202/656] - Обработка товара: 🇷🇺HONOR X9b 5G 8+256GB GREEN 20500₽
# [203/656] - Обработка товара: 🇷🇺HONOR 200 8+256GB GREEN 31000₽
# [204/656] - Обработка товара: 🇷🇺HONOR 200 8+256GB WHITE 31000₽9
# [205/656] - Обработка товара: 🇷🇺HONOR 200 LITE 8+256GB BLACK 17300₽2
# [206/656] - Обработка товара: 🇷🇺HONOR 200 LITE 8+256GB BLUE 17300₽
# [207/656] - Обработка товара: 🇷🇺HONOR 200 LITE 8+256GB GREEN 17300₽
# [208/656] - Обработка товара: 🇷🇺HONOR 200 PRO 12+512GB BLACK 50000₽
# [209/656] - Обработка товара: 🇷🇺INFINIX SMART 9 3+128GB GREEN 7450₽
# [210/656] - Обработка товара: 🇷🇺INFINIX SMART 9 3+128GB GOLD 7450₽
# [211/656] - Обработка товара: 🇷🇺INFINIX NOTE 30I 8+128GB BLACK 11200₽
# [212/656] - Обработка товара: 🇷🇺INFINIX ZERO 40 8+256GB BLACK 20100₽
# [213/656] - Обработка товара: 🇷🇺INFINIX ZERO 40 8+256GB GLOW 20100₽
# [214/656] - Обработка товара: 🇷🇺INFINIX ZERO 40 8+256GB AQUA 20100₽
# [215/656] - Обработка товара: 🇷🇺INFINIX HOT 50I 4+128GB BLACK 8550₽
# [216/656] - Обработка товара: 🇷🇺INFINIX HOT 50I 4+128GB GRAY 8550₽
# [217/656] - Обработка товара: 🇷🇺INFINIX HOT 50I 4+128GB GREEN 8550₽
# [218/656] - Обработка товара: 🇷🇺INFINIX HOT 50I 6+128GB BLACK 9200₽
# [219/656] - Обработка товара: 🇷🇺INFINIX HOT 50I 6+128GB GREY 9200₽
# [220/656] - Обработка товара: 🇷🇺INFINIX HOT 50I 6+128GB GREEN 9200₽
# [221/656] - Обработка товара: 🇷🇺INFINIX HOT 50I 6+128GB PURPLE 9200₽9
# [222/656] - Обработка товара: 🇷🇺INFINIX HOT 50I 4+256GB BLACK  9600₽
# [223/656] - Обработка товара: 🇷🇺INFINIX HOT 50I 4+256GB GREEN  9600₽
# [224/656] - Обработка товара: 🇷🇺INFINIX HOT 50I 4+256GB GRAY  9600₽
# [225/656] - Обработка товара: 🇷🇺INFINIX HOT 50I 4+256GB PURPLE 9600₽
# [226/656] - Обработка товара: 🇷🇺INFINIX HOT 50 6+256GB BLACK 12150₽
# [227/656] - Обработка товара: 🇷🇺INFINIX HOT 50 6+256GB GRAY 12150₽
# [228/656] - Обработка товара: 🇷🇺INFINIX HOT 50 6+256GB GREEN 12150₽
# [229/656] - Обработка товара: 🇷🇺INFINIX HOT 50 8+256GB BLACK 12350₽
# [230/656] - Обработка товара: 🇷🇺INFINIX HOT 50 8+256GB GRAY 12350₽
# [231/656] - Обработка товара: 🇷🇺INFINIX HOT 50 8+256GB GREEN 12350₽3
# [232/656] - Обработка товара: 🇷🇺INFINIX HOT 50 PRO 8+128GB GREY 13600₽
# [233/656] - Обработка товара: 🇷🇺INFINIX HOT 50 PRO 8+128GB BLACK 13600₽
# [234/656] - Обработка товара: 🇷🇺INFINIX HOT 50 PRO 8+128GB BLUE 13600₽
# [235/656] - Обработка товара: 🇷🇺INFINIX NOTE 40 PRO 12+256GB BLACK 22400₽
# [236/656] - Обработка товара: 🇷🇺INFINIX NOTE 40 PRO 12+256GB GRAY 22400₽
# [237/656] - Обработка товара: 🇷🇺INFINIX HOT 50 PRO +256GB GREY 15600₽1
# [238/656] - Обработка товара: 🇷🇺REALME 12 8+256GB GREEN 15300₽
# [239/656] - Обработка товара: 🇷🇺REALME 12 8+256GB BLUE 15300₽
# [240/656] - Обработка товара: 🇷🇺REALME NOTE 50 4 128GB BLACK 6900₽
# [241/656] - Обработка товара: 🇷🇺REALME NOTE 60X 3+64GB GREEN 6300₽
# [242/656] - Обработка товара: 🇷🇺REALME NOTE 60X 3+64GB BLACK 6300₽
# [243/656] - Обработка товара: 🇷🇺REALME NOTE 60 4+128GB BLACK 7500₽
# [244/656] - Обработка товара: 🇷🇺REALME NOTE 60 4+128GB BLUE 7500₽
# [245/656] - Обработка товара: 🇷🇺REALME C61 6+128GB GOLD 8350₽
# [246/656] - Обработка товара: 🇷🇺REALME C61 6+128GB GREEN 8350₽
# [247/656] - Обработка товара: 🇷🇺REALME C61 8+128GB GREEN 9900₽
# [248/656] - Обработка товара: 🇷🇺REALME C61 8+256GB GOLD 10500₽
# [249/656] - Обработка товара: 🇷🇺REALME C61 8+256GB GREEN 10500₽
# [250/656] - Обработка товара: 🇷🇺REALME C63 6+128Gb BLUE 9900₽
# [251/656] - Обработка товара: 🇷🇺REALME C67 8+256GB BLACK 13500₽1
# [252/656] - Обработка товара: 🎧AirPods MAX Gray  44000
# [253/656] - Обработка товара: 🎧AirPods MAX Blue   44000
# [254/656] - Обработка товара: 🎧AirPods MAX Green   44400
# [255/656] - Обработка товара: 🎧AirPods MAX Pink   44400
# [256/656] - Обработка товара: 🎧AirPods MAX (USB-C) Midnight   50900
# [257/656] - Обработка товара: 🎧AirPods MAX (USB-C) Blue  50900
# [258/656] - Обработка товара: 🎧AirPods MAX (USB-C) Purple   52000
# [259/656] - Обработка товара: 🎧AirPods MAX (USB-C) Orange   52000
# [260/656] - Обработка товара: 🎧AirPods 2   8300
# [261/656] - Обработка товара: (От 10шт )  8100
# [262/656] - Обработка товара: 🎧 AirPods 3 Lighting  11200
# [263/656] - Обработка товара: (От 10шт )  11000
# [264/656] - Обработка товара: 🎧AirPods 4   12200
# [265/656] - Обработка товара: (От 10шт )  12000
# [266/656] - Обработка товара: 🎧AirPods 4  ANC 15800
# [267/656] - Обработка товара: 🎧AirPods Pro 2 TYPE-C  18600
# [268/656] - Обработка товара: (От 10шт )  18400
# [269/656] - Обработка товара: SE2 40 Black SB (S/M) 🇺🇸 17300 🚕
# [270/656] - Обработка товара: SE2 40 Starlight SB (S/M) 🇺🇸 17600 🚕
# [271/656] - Обработка товара: SE2 40 Silver State Blue (M/L) 🇺🇸 17600
# [272/656] - Обработка товара: SE2 44 Midnight SB (M/L) 🇺🇸 20000
# [273/656] - Обработка товара: SE2 44 Midnight SB (S/M) 🇺🇸 20000
# [274/656] - Обработка товара: SE2 44 Silver Winter Blue SB (M/L) 2023 🇺🇸 20300
# [275/656] - Обработка товара: SE2 40 Black SB (S/M) 2024 🇺🇸 17700
# [276/656] - Обработка товара: SE2 44 Midnight SB (S/M) 2024 🇺🇸 20500
# [277/656] - Обработка товара: SE2 44 Midnight SB (M/L) 2024 🇺🇸 20500
# [278/656] - Обработка товара: S9 45 Midnight (S/M) 🇺🇸 29900 🚕
# [279/656] - Обработка товара: S9 45 Silver (S/M) 🇺🇸 31000
# [280/656] - Обработка товара: S9 45 Silver (M/L) 🇺🇸 31000
# [281/656] - Обработка товара: S10 42 Jet Black (M/L) 🇺🇸 35300
# [282/656] - Обработка товара: S10 42 Silver (M/L) 🇺🇸 36400
# [283/656] - Обработка товара: S10 42 Silver (M/L) Pure Platinum Nike SB 🇺🇸 36200
# [284/656] - Обработка товара: S10 42 Jet Black (M/L) Midnight Sky Nike SB 🇺🇸 36200
# [285/656] - Обработка товара: S10 46 Jet Black (M/L) 🇺🇸 37800
# [286/656] - Обработка товара: S10 46 Rose Gold (S/M) 🇺🇸 38300
# [287/656] - Обработка товара: S10 46 Rose Gold Plum SL 🇺🇸 38000
# [288/656] - Обработка товара: S10 46 Silver (M/L) 🇺🇸 38500
# [289/656] - Обработка товара: S10 46 Silver (S/M) 🇺🇸 38500
# [290/656] - Обработка товара: S10 46 Rose Gold (M/L) 🇺🇸 38000
# [291/656] - Обработка товара: UL 2 Olive - AL (S) 🇺🇸 68000
# [292/656] - Обработка товара: UL 2 Olive - AL (M) 🇺🇸 68000
# [293/656] - Обработка товара: UL 2 Blue Black - TL (S/M) 🇺🇸 68000
# [294/656] - Обработка товара: UL 2 Natural / Tan AL S (2024) 🇺🇸 75500
# [295/656] - Обработка товара: UL 2 Black / Dark Green AL S (2024) 🇺🇸 74800
# [296/656] - Обработка товара: UL 2 Black / Dark Green AL M (2024) 🇺🇸 74000 🚕
# [297/656] - Обработка товара: 🎮 Sony Dual Sense Black  6900
# [298/656] - Обработка товара: 🎮 Sony Dual Sense White  6900
# [299/656] - Обработка товара: 🎮 Sony Dual Sense Red 6900
# [300/656] - Обработка товара: ⌨️12.9 Folio (MXNL2) 🇺🇸 21000
# [301/656] - Обработка товара: iPad 10 256 Blue Wi-Fi 🇺🇸 42800
# [302/656] - Обработка товара: MINI 6 256 Silver LTE 🇺🇸 73500
# [303/656] - Обработка товара: MINI 6 256 Pink LTE 🇺🇸 73500
# [304/656] - Обработка товара: AIR 5 64 Gray Wi-Fi 🇺🇸 44300
# [305/656] - Обработка товара: AIR 5 64 Blue Wi-Fi 🇺🇸 44300
# [306/656] - Обработка товара: AIR 11 M2 256 Gray Wi-Fi 🇺🇸 67000 🚕
# [307/656] - Обработка товара: PRO 11 M4 256 Black  Wi-Fi 🇺🇸 91500
# [308/656] - Обработка товара: PRO 11 M4 256 Silver Wi-Fi 🇺🇸 91500
# [309/656] - Обработка товара: PRO 13 M4 256 Black  Wi-Fi 🇺🇸 123000
# [310/656] - Обработка товара: PRO 13 M4 256 Black  LTE 🇺🇸 129500
# [311/656] - Обработка товара: PRO 13 M4 256 Silver LTE 🇺🇸 132500
# [312/656] - Обработка товара: 🖥 iMac 24 (MGPL3) Blue  135000
# [313/656] - Обработка товара: 💻Air 13  (MC7X4) Midnight  84000
# [314/656] - Обработка товара: 💻Air 13  (MC8K4) Midnight  97500
# [315/656] - Обработка товара: 💻 Pro 14 (MRX33) Space Black  163500
# [316/656] - Обработка товара: 💻 Pro 14 (MRX63) Silver  165500
# [317/656] - Обработка товара: 💻 Pro 16 (Z1CM000M9) Space Black   720000
# [318/656] - Обработка товара: 11 64 Black 🇦🇪(Slim)  32800
# [319/656] - Обработка товара: 11 64 White 🇦🇪(Slim)  33700
# [320/656] - Обработка товара: 12 Mini 64 White 🇺🇸  43500
# [321/656] - Обработка товара: 12 Mini 64 Red🇯🇵 43000
# [322/656] - Обработка товара: 12 Mini 64 Blue🇯🇵 43500
# [323/656] - Обработка товара: 12 64 Black 🇦🇪 36800
# [324/656] - Обработка товара: 12 64 White 🇦🇪 36800 🚙
# [325/656] - Обработка товара: 12 64 Purple 🇦🇪 36800
# [326/656] - Обработка товара: 12 64 Green 🇦🇪 36400
# [327/656] - Обработка товара: 12 128 Black 🇦🇪 39500 🚙
# [328/656] - Обработка товара: 12 128 Purple🇦🇪 39300 🚙
# [329/656] - Обработка товара: 12 128 Green 🇦🇪 41300 🚙
# [330/656] - Обработка товара: 12 256 Purple 🇨🇳 49500
# [331/656] - Обработка товара: 13 128 Midnight 🇮🇳 45600 🚙
# [332/656] - Обработка товара: 13 128 Green 🇮🇳 44800 🚙
# [333/656] - Обработка товара: 13 128 Blue 🇮🇳 45500 🚙
# [334/656] - Обработка товара: 13 256 Red 🇦🇪 59700
# [335/656] - Обработка товара: 13 256 Pink 🇮🇳 62400 🚕
# [336/656] - Обработка товара: 13 512 Red🇦🇪 60900 🚕
# [337/656] - Обработка товара: 13 512 Pink🇯🇵 65800
# [338/656] - Обработка товара: 13 512 Green 🇦🇪 61700 🚙
# [339/656] - Обработка товара: 14 128 Red  🇦🇪 50900 🚙
# [340/656] - Обработка товара: 14 128 Yellow 🇮🇳 50900 🚙
# [341/656] - Обработка товара: 14 256 Red  🇦🇪 69500
# [342/656] - Обработка товара: 14 256 Purple  🇦🇪 68400
# [343/656] - Обработка товара: 14 256 Blue 🇦🇪 68000 🚙
# [344/656] - Обработка товара: 14 256 Yellow 🇦🇪 67500
# [345/656] - Обработка товара: 14 512 Midnight 🇦🇪 74500
# [346/656] - Обработка товара: 14 512 Starlight 🇦🇪 74000 🚙
# [347/656] - Обработка товара: 14 512 Red  🇦🇪 74000
# [348/656] - Обработка товара: 14 512 Blue  🇦🇪 74000
# [349/656] - Обработка товара: 14 512 Yellow 🇦🇪 74000
# [350/656] - Обработка товара: 14 Plus 128 Yellow 🇦🇪 59500
# [351/656] - Обработка товара: 14 Plus 128 Yellow 🇯🇵 59400 🚙
# [352/656] - Обработка товара: 14 Plus  512 Red 🇯🇵 70500
# [353/656] - Обработка товара: 14 Plus  512 Yellow 🇦🇪 70500
# [354/656] - Обработка товара: 14 Pro Max 512 Gold 🇮🇳 110000
# [355/656] - Обработка товара: 15 128 Midnight 🇮🇳  62100
# [356/656] - Обработка товара: 15 128 Pink 🇮🇳  62300  🚙
# [357/656] - Обработка товара: 15 128 Blue 🇮🇳  64000
# [358/656] - Обработка товара: 15 128 Green 🇮🇳  62300
# [359/656] - Обработка товара: 15 256 Midnight 🇮🇳  73100  🚘
# [360/656] - Обработка товара: 15 256 Pink 🇮🇳  73900  🚕
# [361/656] - Обработка товара: 15 256 Blue 🇦🇪  72900  🚕
# [362/656] - Обработка товара: 15 256 Green 🇦🇪  72500
# [363/656] - Обработка товара: 15 Plus 128 Midnight 🇦🇪  67100
# [364/656] - Обработка товара: 15 Plus 128 Pink🇮🇳  66500
# [365/656] - Обработка товара: 15 Plus  512 Midnight 🇦🇪  98000
# [366/656] - Обработка товара: 15 Pro 128 White 🇦🇪  90600
# [367/656] - Обработка товара: 15 Pro 128 Blue 🇦🇪  90600
# [368/656] - Обработка товара: 15 Pro 128 Natural 🇦🇪  94700
# [369/656] - Обработка товара: 15 Pro Max 256 Blue 🇦🇪  101700  🚙
# [370/656] - Обработка товара: 15 Pro Max 256 Natural 🇦🇪  101400
# [371/656] - Обработка товара: 16 128 White 🇮🇳 70000
# [372/656] - Обработка товара: 16 128 Pink 🇮🇳 70100
# [373/656] - Обработка товара: 16 128 Teal 🇮🇳 69500
# [374/656] - Обработка товара: 16 256 Black 🇦🇪 81500 🚙
# [375/656] - Обработка товара: 16 256 White 🇦🇪 81500 🚙
# [376/656] - Обработка товара: 16 256 Pink 🇦🇪 82300
# [377/656] - Обработка товара: 16 256 Teal 🇦🇪 81500
# [378/656] - Обработка товара: 16 256 Ultramarine 🇦🇪 81500 🚙
# [379/656] - Обработка товара: 16 Plus  128 Black 🇮🇳 81900
# [380/656] - Обработка товара: 16 Plus  128 White 🇮🇳 82400
# [381/656] - Обработка товара: 16 Plus  128 Teal 🇦🇪 82500
# [382/656] - Обработка товара: 16 Plus  128 Ultramarine 🇦🇪 82500
# [383/656] - Обработка товара: 16 Pro 128 Black 🇦🇪 95700
# [384/656] - Обработка товара: 16 Pro 128 White 🇦🇪 95500
# [385/656] - Обработка товара: 16 Pro 128 Natural 🇦🇪 95800
# [386/656] - Обработка товара: 16 Pro 128 Desert 🇯🇵 95900
# [387/656] - Обработка товара: 16 Pro 256 Black 🇯🇵 104000 🚙
# [388/656] - Обработка товара: 16 Pro 256 White 🇯🇵 104200
# [389/656] - Обработка товара: 16 Pro 256 Natural 🇯🇵 103800 🚙
# [390/656] - Обработка товара: 16 Pro 256 Desert 🇯🇵 104100 🚙
# [391/656] - Обработка товара: 16 Pro 512 White 🇯🇵 118000 🚙
# [392/656] - Обработка товара: 16 Pro 512 Natural 🇯🇵  120300 🚘
# [393/656] - Обработка товара: 16 Pro Max 256 Black 🇯🇵 113500 🚙
# [394/656] - Обработка товара: 16 Pro Max 256 White 🇦🇪 114400
# [395/656] - Обработка товара: 16 Pro Max 256 Natural 🇦🇪 113700 🚙
# [396/656] - Обработка товара: 16 Pro Max 256 Desert 🇦🇪 114400 🚙
# [397/656] - Обработка товара: 16 Pro Max 1TB White 🇯🇵 151800 🚘
# [398/656] - Обработка товара: 16 Pro Max 1TB Natural 🇯🇵 151200 🚙
# [399/656] - Обработка товара: YouTakeAll ОПТ, [28.01.2025 10:19]
# [400/656] - Обработка товара: Meta Oculus Quest 3S 256GB🇯🇵 41700
# [401/656] - Обработка товара: Steam Deck OLED 1TB🇬🇧 67200
# [402/656] - Обработка товара: XBOX Series  S 512GB White🇪🇺 31800
# [403/656] - Обработка товара: XBOX Series S 1TB Carbon Black🇬🇧 40500
# [404/656] - Обработка товара: Sony PlayStation 4 Slim R3 1Tb🇯🇵 30600
# [405/656] - Обработка товара: Sony WH-1000XM4 Black🇯🇵 20500
# [406/656] - Обработка товара: Sony WH-1000XM5 HeadPhone Black🇯🇵 25400
# [407/656] - Обработка товара: Sony WH-1000XM5/SM Platinum Silver🇯🇵 25400
# [408/656] - Обработка товара: Sony Xperia 1IV Gaming Edition 16/512 Black XQ-CT72🇨🇳 71700
# [409/656] - Обработка товара: Pixel 6A 128 Charcoal🇺🇸 28100
# [410/656] - Обработка товара: Pixel 6 Pro 128 Black🇯🇵 31900
# [411/656] - Обработка товара: Pixel 6 Pro 128 Sorta Sunny🇯🇵  31900
# [412/656] - Обработка товара: Pixel 6 Pro 128 White🇯🇵 31900
# [413/656] - Обработка товара: Pixel 6 Pro 256 Stormy Black🇯🇵  35700
# [414/656] - Обработка товара: Pixel 6 Pro 256 Cloudy White🇺🇸 35700
# [415/656] - Обработка товара: Pixel 7 128 Snow🇮🇳 30900
# [416/656] - Обработка товара: Pixel 7 128 Lemongrass🇮🇳 30600
# [417/656] - Обработка товара: Pixel 9 Pro XL 5G 256 Rose Quartz🇯🇵 86500
# [418/656] - Обработка товара: Pixel Watch 2 LTE Matte Black Case / Obsidian Active Band🇬🇧 21500
# [419/656] - Обработка товара: Pixel Watch 2 LTE Polished Silver Case / Bay Band🇺🇸 21500
# [420/656] - Обработка товара: Pixel Watch 2 LTE Polished Silver Case / Porcelian Band🇬🇧 21500
# [421/656] - Обработка товара: Pixel Watch 2 LTE Champagne Gold Case / Hazel Active Band🇬🇧 21500
# [422/656] - Обработка товара: Pixel Watch 3 WI-FI 45mm Polished Silver Case / Porcelian Active Band🇺🇸 28200
# [423/656] - Обработка товара: Hero 11 Black Mini🇺🇸 20000
# [424/656] - Обработка товара: GoPro Hero 4K🇪🇺 20800
# [425/656] - Обработка товара: Huawei Pura 70 Ultra 16/512 Black HBP-LX9🇬🇧 83500
# [426/656] - Обработка товара: Huawei Pura 70 Ultra 16/512 Green HBP-LX9🇬🇧 83500
# [427/656] - Обработка товара: A14 4/64 Black SM-A145F/DS🇦🇪 11900
# [428/656] - Обработка товара: A14 4/64 Light Green SM-A145P/DS🇦🇪 11900
# [429/656] - Обработка товара: A16 4/128 Black SM-A165F/DS🇦🇪 12800
# [430/656] - Обработка товара: A16 4/128 Gray SM-A165F/DS🇦🇪 12800
# [431/656] - Обработка товара: A16 4/128 Light Green SM-A165F/DS🇦🇪 12800
# [432/656] - Обработка товара: A16 5G 4/128 Blue Black SM-A166E/DS🇦🇪 16000
# [433/656] - Обработка товара: A16 5G 4/128 Light Gray SM-A166E/DS🇦🇪 16000
# [434/656] - Обработка товара: A16 5G 4/128 Light Green SM-A166E/DS🇦🇪 16000
# [435/656] - Обработка товара: A25 5G 6/128 Blue Black SM-A256E/DSN🇦🇪 17000
# [436/656] - Обработка товара: A25 5G 6/128 Blue Black SM-A256E/DSN🇰🇿 17000
# [437/656] - Обработка товара: A25 5G 6/128 Light Blue SM-A256E/DSN🇦🇪 17000
# [438/656] - Обработка товара: A25 5G 6/128 Yellow SM-A256E/DSN🇦🇪 17000
# [439/656] - Обработка товара: A35 5G 8/128 Navy SM-A356E/DS🇦🇪 23000
# [440/656] - Обработка товара: A35 5G 8/128 Navy SM-A356E/DS🇰🇿 23000
# [441/656] - Обработка товара: A35 5G 8/128 Ice Blue SM-A356E/DS🇰🇿 23000
# [442/656] - Обработка товара: A35 5G 8/128 Lemon SM-A356E/DS🇦🇪 23000
# [443/656] - Обработка товара: A35 5G 8/128 Ice Blue SM-A356E/DS🇦🇪 23000
# [444/656] - Обработка товара: A35 5G 8/128 Lilac SM-A356E/DS🇰🇿 23000
# [445/656] - Обработка товара: A35 5G 8/256 Ice Blue SM-A356E/DS🇰🇿 24300
# [446/656] - Обработка товара: A35 5G 8/256 Ice Blue SM-A356E/DS🇦🇪 24300
# [447/656] - Обработка товара: A35 5G 8/256 Navy SM-A356E/DS🇰🇿 24600
# [448/656] - Обработка товара: A35 5G 8/256 Navy SM-A356E/DS🇦🇪 24600
# [449/656] - Обработка товара: A35 5G 8/256 Lilac SM-A356ELV/DS🇰🇿 24300
# [450/656] - Обработка товара: A35 5G 8/256 Lilac SM-A356E/DS🇦🇪 24300
# [451/656] - Обработка товара: A35 5G 8/256 Lemon SM-A356E/DS🇦🇪 24300
# [452/656] - Обработка товара: A55 5G 8/128 Ice Blue SM-A556E/DS🇦🇪 27400
# [453/656] - Обработка товара: A55 5G 8/128 Navy SM-A556E/DS🇦🇪 27900
# [454/656] - Обработка товара: A55 5G 8/128 Lemon SM-A556E/DS🇨🇱 27900
# [455/656] - Обработка товара: A55 5G 8/128 Lemon SM-A556E/DS🇦🇪 27900
# [456/656] - Обработка товара: A55 5G 8/256 Navy SM-A556E/DS🇦🇪 31300
# [457/656] - Обработка товара: A55 5G 12/256 Navy SM-A556E/DS🇲🇾распак 31700
# [458/656] - Обработка товара: A55 5G 12/256 Iceblue SM-A556E/DS🇲🇾распак 31700
# [459/656] - Обработка товара: A55 5G 12/256 Lilac SM-A556E/DS🇲🇾распак 31700
# [460/656] - Обработка товара: S22 8/128 Black SM-S901B/DS🇪🇺 41700
# [461/656] - Обработка товара: S22 8/256 Purple S901E/DS🇦🇪 46000
# [462/656] - Обработка товара: S22+ 8/128 White SM-S906E/DS🇦🇪 51000
# [463/656] - Обработка товара: S22+ 8/256 Black SM-S906E/DS🇦🇪 53000
# [464/656] - Обработка товара: S22+ 8/256 White SM-S906E/DS🇦🇪 53000
# [465/656] - Обработка товара: S22 Ultra 8/128 Black SM-S908B/DS🇦🇪 61700
# [466/656] - Обработка товара: S22 Ultra 12/256 Burgundy SM-S908E/DS🇹🇭распак 65500
# [467/656] - Обработка товара: S22 Ultra 12/512 Black SM-S908E/DS🇦🇪 75500
# [468/656] - Обработка товара: S22 Ultra 12/512 White SM-S908E/DS🇦🇪 75500
# [469/656] - Обработка товара: S23 FE 8/128 Graphite SM-711B/DS🇮🇳распак 33200
# [470/656] - Обработка товара: S23 FE 8/256 Mint SM-711B/DS🇮🇳распак 39500
# [471/656] - Обработка товара: S23 8/128 Black SM-911B/DS🇮🇳распак 42700
# [472/656] - Обработка товара: S23 8/128 Cream SM-S911B/DS🇮🇳распак 42700
# [473/656] - Обработка товара: S23 Ultra 12/256 Black SM-S918B/DS🇦🇪 68000
# [474/656] - Обработка товара: S24 FE 8/256 Gray SM-S721B/DS🇦🇪 43900
# [475/656] - Обработка товара: S24 FE 8/256 Mint SM-S721B/DS🇦🇪 43900
# [476/656] - Обработка товара: S24 FE 8/256 Blue SM-S721B/DS🇦🇪 43900
# [477/656] - Обработка товара: S24 FE 8/512 Graphite SM-S721B/DS🇦🇪 58600
# [478/656] - Обработка товара: S24 FE 8/512 Gray SM-S721B/DS🇲🇾распак 58000
# [479/656] - Обработка товара: S24 FE 8/512 Gray SM-S721B/DS🇦🇪 58600
# [480/656] - Обработка товара: S24 8/128 Black SM-S921B/DS🇵🇾(распак) 54500
# [481/656] - Обработка товара: S24 8/128 Black SM-S921B/DS🇰🇿 55300
# [482/656] - Обработка товара: S24 8/128 Marble Gray SM-S921B/DS🇵🇾(распак) 54500
# [483/656] - Обработка товара: S24 8/128 Violet SM-S921B/DS🇵🇾(распак) 54500
# [484/656] - Обработка товара: S24 8/128 Violet SM-S921B/DS🇰🇿 55300
# [485/656] - Обработка товара: S24 8/128 Violet SM-S921B/DS🇨🇱 54500
# [486/656] - Обработка товара: S24 8/128 Yellow SM-S921B/DS🇰🇿 55300
# [487/656] - Обработка товара: S24 8/256 Gray SM-S9210🇭🇰распак 58700
# [488/656] - Обработка товара: S24 8/256 Jade Green SM-S921B/DS🇦🇪 61500
# [489/656] - Обработка товара: YouTakeAll ОПТ, [28.01.2025 10:19]
# [490/656] - Обработка товара: S24 + 12/256 Black SM-S926B/DS🇦🇪 68300
# [491/656] - Обработка товара: S24 + 12/256 Black SM-S926B/DS🇮🇳(распак) 66200
# [492/656] - Обработка товара: S24 + 12/256 Gray SM-S926B/DS🇦🇪 68000
# [493/656] - Обработка товара: S24 + 12/256 Violet SM-S926B/DS🇦🇪 68000
# [494/656] - Обработка товара: S24 Ultra 12/256 Black SM-S928B/DS🇨🇱 79000
# [495/656] - Обработка товара: S24 Ultra 12/256 Black SM-S928B/DS🇲🇾распак 79000
# [496/656] - Обработка товара: S24 Ultra 12/256 Grey SM-S928B/DS🇲🇾распак 79000
# [497/656] - Обработка товара: S24 Ultra 12/256 Violet SM-S928B/DS🇲🇾распак 79000
# [498/656] - Обработка товара: S24 Ultra 12/512 Black SM-S928B/DS🇦🇪 93000
# [499/656] - Обработка товара: S24 Ultra 12/512 Black SM-S928B/DS🇪🇺 93000
# [500/656] - Обработка товара: S24 Ultra 12/512 Gray SM-S928B/DS🇪🇺 93000
# [501/656] - Обработка товара: Z Flip6 12/256 Blue SM-F741B🇲🇾распак 70600
# [502/656] - Обработка товара: Z Flip6 12/256 Mint SM-F741B🇲🇾распак 70600
# [503/656] - Обработка товара: Z Flip6 12/512 Silver Shadow SM-F741B🇰🇿 74500
# [504/656] - Обработка товара: Z Flip6 12/512 Silver Shadow SM-F741B🇦🇪 74500
# [505/656] - Обработка товара: Z Flip6 12/512 Blue SM-F741B🇰🇿 74500
# [506/656] - Обработка товара: Z Flip6 12/512 Blue SM-F741B🇦🇪 74500
# [507/656] - Обработка товара: Z Flip6 12/512 Blue SM-F741B🇲🇾распак 74200
# [508/656] - Обработка товара: Z Flip6 12/512 Peach SM-F741B🇲🇾распак 74200
# [509/656] - Обработка товара: Z Flip6 12/512 Yellow SM-F741B🇦🇪 74200
# [510/656] - Обработка товара: Z Fold5 12/256 Black SM-F946B/DS🇿🇦 93700
# [511/656] - Обработка товара: Z Fold5 12/256 Ice Blue SM-F946B/DS🇿🇦 93700
# [512/656] - Обработка товара: Z Fold5 12/1TB Cream SM-F946B/DS🇲🇾распак 104000
# [513/656] - Обработка товара: Z Fold6 12/256 Pink SM-F956B/DS🇰🇿 117000
# [514/656] - Обработка товара: Z Fold6 12/512 Pink SM-F956B/DS🇰🇿 127700
# [515/656] - Обработка товара: Galaxy Buds 3 White SM-R530🇦🇪 8600
# [516/656] - Обработка товара: Galaxy Buds 3 White SM-R530🇹🇭 8600
# [517/656] - Обработка товара: Buds 3 Pro White SM-R630🇬🇧 14100
# [518/656] - Обработка товара: Buds 3 Pro White SM-R630🇦🇪 14100
# [519/656] - Обработка товара: Galaxy Watch4 46mm Classic SM-R890 Black🇪🇺 11700
# [520/656] - Обработка товара: Galaxy Watch6 Classic 43mm Black SM-R950🇦🇪 15800
# [521/656] - Обработка товара: Galaxy Watch6 Classic 47mm LTE Silver SM-R965F🇦🇪 21800
# [522/656] - Обработка товара: Galaxy Watch7 44mm Silver SM-L310🇦🇪 20900
# [523/656] - Обработка товара: Redmi 12 8/256 Blue NFC🇷🇺 10200
# [524/656] - Обработка товара: Redmi 13 6/128 Black🇷🇺 10600
# [525/656] - Обработка товара: Redmi 13 6/128 Gold🇷🇺 10600
# [526/656] - Обработка товара: Redmi 13 8/256 Black🇷🇺 13200
# [527/656] - Обработка товара: Redmi 13 8/256 Blue🇷🇺 13200
# [528/656] - Обработка товара: Redmi 14C 4/128 Midnight Black🇷🇺 8000
# [529/656] - Обработка товара: Redmi 14C 4/128 Dreamy Purple🇷🇺 8000
# [530/656] - Обработка товара: Redmi 14C 4/128 Sage Green🇷🇺 8000
# [531/656] - Обработка товара: Redmi 14C 4/128 Starry Blue🇷🇺 8000
# [532/656] - Обработка товара: Redmi 14C 8/256 Midnight Black🇷🇺 10000
# [533/656] - Обработка товара: Redmi 14C 8/256 Sage Green🇷🇺 10000
# [534/656] - Обработка товара: Redmi 14C 8/256 Starry Blue🇷🇺 10000
# [535/656] - Обработка товара: Note 13 Pro 12/512 Midnight Black🇷🇺 25500
# [536/656] - Обработка товара: GARMIN VIVOSMART 5 WHITE S/M 010-02645-11🇪🇺 12000
# [537/656] - Обработка товара: GARMIN MARQ GOLFER (GEN 2) - CARBON EDITION 010-02722-21🇪🇺 235000
# [538/656] - Обработка товара: Garmin Fenix E 47 MM AMOLED SlateGray 010-03025-01🇪🇺 62000
# [539/656] - Обработка товара: Garmin Fenix E 47 MM AMOLED Stainless 010-03025-00🇪🇺 62000
# [540/656] - Обработка товара: GARMIN EPIX PRO (GEN 2) SAPPHIRE EDITION 42MM SOFT GOLD 010-02802-20🇪🇺 83500
# [541/656] - Обработка товара: GARMIN EPIX PRO (GEN 2) SAPPHIRE EDITION 42MM CARBON 010-02802-15🇪🇺 78000
# [542/656] - Обработка товара: GARMIN EPIX PRO (GEN 2) STANDARD EDITION 42MM SILVER 010-02802-11🇪🇺 78000
# [543/656] - Обработка товара: GARMIN EPIX PRO (GEN 2) STANDARD EDITION 51MM SLATE GRAY 010-02804-21🇪🇺 79000
# [544/656] - Обработка товара: GARMIN EPIX PRO (GEN 2) SAPPHIRE EDITION 51MM CARBON GRAY 010-02804-30🇪🇺 91000
# [545/656] - Обработка товара: GARMIN EPIX PRO (GEN 2) SAPPHIRE EDITION 51MM CARBON GRAY 010-02804-01🇪🇺 88000
# [546/656] - Обработка товара: GARMIN EPIX PRO (GEN 2) STANDARD EDITION 42MM SILVER 010-02802-01🇪🇺 69000
# [547/656] - Обработка товара: AirPods 4 (HN) - 13000
# [548/656] - Обработка товара: AirPods Pro 2 Type-C (LL) - 19600
# [549/656] - Обработка товара: AirPods Max Silver - 47000
# [550/656] - Обработка товара: AirPods Max 2 Starlight - 55000
# [551/656] - Обработка товара: AirPods Max 2 Purple - 55000
# [552/656] - Обработка товара: Pencil USB-С (ZA) - 9300
# [553/656] - Обработка товара: Pencil Pro (ZA) - 12500
# [554/656] - Обработка товара: 12 128 Purple - 41000🇵🇾
# [555/656] - Обработка товара: 14 128 Red - 53000🇮🇳
# [556/656] - Обработка товара: 14 128 Yellow - 52500🇮🇳
# [557/656] - Обработка товара: 14 256 Midnight - 71000🇯🇵🇮🇳
# [558/656] - Обработка товара: 14 256 Midnight - 72000🇪🇺
# [559/656] - Обработка товара: 14 256 Blue - 73000🇮🇳
# [560/656] - Обработка товара: 14 256 Purple - 71500🇮🇳
# [561/656] - Обработка товара: 14 512 Purple - 77000🇪🇺
# [562/656] - Обработка товара: 14 512 Red - 74000🇪🇺
# [563/656] - Обработка товара: 14 512 Yellow - 74000🇪🇺
# [564/656] - Обработка товара: 14 Plus 512 Starlight - 80000🇨🇦
# [565/656] - Обработка товара: 14 Plus 512 Blue - 81000🇨🇦
# [566/656] - Обработка товара: 14 Plus 512 Purple - 81000🇨🇦
# [567/656] - Обработка товара: 14 Plus 512 Yellow - 78000🇨🇦🇦🇪
# [568/656] - Обработка товара: 15 128 Black - 63000🇯🇵
# [569/656] - Обработка товара: 15 128 Blue - 65000🇮🇳
# [570/656] - Обработка товара: 15 128 Pink - 64500🇮🇳
# [571/656] - Обработка товара: 15 128 Green - 63000🇯🇵
# [572/656] - Обработка товара: 15 256 Black - 75000🇮🇳
# [573/656] - Обработка товара: 15 256 Black - 75500🇪🇺
# [574/656] - Обработка товара: 15 256 Blue - 75000🇮🇳
# [575/656] - Обработка товара: 15 256 Green - 75000🇮🇳
# [576/656] - Обработка товара: 15 256 Green - 75500🇪🇺
# [577/656] - Обработка товара: 15 256 Pink - 75000🇮🇳
# [578/656] - Обработка товара: 15 256 Yellow - 80000🇦🇪
# [579/656] - Обработка товара: 15 Pro Max 1Tb Black - 131000🇮🇳
# [580/656] - Обработка товара: 15 Pro Max 1Tb Blue - 130000🇪🇺
# [581/656] - Обработка товара: 15 Pro Max 1Tb Natural - 133000🇸🇬
# [582/656] - Обработка товара: 15 Pro Max 1Tb Natural - 134000🇪🇺
# [583/656] - Обработка товара: 16 128 Black - 74000🇮🇳
# [584/656] - Обработка товара: 16 128 Pink - 74000🇮🇳
# [585/656] - Обработка товара: 16 128 Teal - 74000🇮🇳
# [586/656] - Обработка товара: 16 128 Ultramarine - 74000🇮🇳
# [587/656] - Обработка товара: 16 256 Ultramarine - 86000🇯🇵
# [588/656] - Обработка товара: SE2 40 S/M silver (2023) - 19600🇺🇸
# [589/656] - Обработка товара: SE2 40 S/M midnight (2024) - 19500🇺🇸
# [590/656] - Обработка товара: SE2 40 S/M silver (2024) - 19800🇺🇸
# [591/656] - Обработка товара: SE2 40 S/M starlight (2024) - 19000🇺🇸
# [592/656] - Обработка товара: SE2 40 Loop starlight/Green (2024) - 19000🇺🇸
# [593/656] - Обработка товара: SE2 44 M/L midnight (2024) - 21800🇺🇸
# [594/656] - Обработка товара: SE2 44 Loop midnight (2024) - 21800🇺🇸
# [595/656] - Обработка товара: SE2 44 M/L starlight (2024) - 22500🇺🇸
# [596/656] - Обработка товара: SE2 44 Loop starlight/Green (2024) - 22500🇺🇸
# [597/656] - Обработка товара: S9 41 M/L Red - 35000🇶🇦
# [598/656] - Обработка товара: S9 45 S/M midnight - 32800🇮🇳
# [599/656] - Обработка товара: S9 45 S/M Silver/Blue - 36000🇮🇳
# [600/656] - Обработка товара: S9 45 M/L Silver/Blue - 36000🇶🇦
# [601/656] - Обработка товара: S9 45 M/L starlight  - 36000🇺🇸🇮🇳
# [602/656] - Обработка товара: S9 45 M/L Red - 36000🇶🇦
# [603/656] - Обработка товара: S9 45 S/M Red - 36000🇶🇦
# [604/656] - Обработка товара: S10 42 S/M Jet Black/Black - 38000🇺🇸
# [605/656] - Обработка товара: S10 42 M/L Jet Black/Black - 38000🇺🇸
# [606/656] - Обработка товара: S10 42 Loop Jet Black/Ink - 38000🇺🇸
# [607/656] - Обработка товара: S10 42 S/M Silver/Denim - 39000🇺🇸
# [608/656] - Обработка товара: S10 42 M/L Silver/Nike - 39000🇺🇸
# [609/656] - Обработка товара: S10 42 Loop Silver/Cloud - 39000🇺🇸
# [610/656] - Обработка товара: S10 42 S/M Rose Gold/L.Blush - 38500🇺🇸
# [611/656] - Обработка товара: S10 42 M/L Rose Gold/L.Blush - 38500🇺🇸
# [612/656] - Обработка товара: S10 46 M/L Silver/Denim - 40000🇺🇸
# [613/656] - Обработка товара: S10 46 M/L Rose Gold/L.Blush - 40500🇺🇸
# [614/656] - Обработка товара: S10 46 M/L Jet Black/Black - 37000🇺🇸(обменка)
# [615/656] - Обработка товара: iPad 10 256 Silver Wi-Fi - 48500🇺🇸
# [616/656] - Обработка товара: iPad 10 256 Blue Wi-Fi - 48500🇺🇸
# [617/656] - Обработка товара: iPad 10 256 Pink Wi-Fi -48500🇦🇪
# [618/656] - Обработка товара: Air 5 64 Gray Wi-Fi - 48500🇦🇪
# [619/656] - Обработка товара: Air 11 M2 128 Starlight Wi-Fi - 60000🇸🇬
# [620/656] - Обработка товара: Air 11 M2 128 Purple Wi-Fi - 59000🇸🇬
# [621/656] - Обработка товара: Pro 13 M4 256 Black Wi-Fi - 123000🇺🇸
# [622/656] - Обработка товара: 🔌 Adapter 25W PD 2-pin Black - 1500
# [623/656] - Обработка товара: Galaxy Buds 3 White - 10000
# [624/656] - Обработка товара: Galaxy Buds 3 Pro White - 15000
# [625/656] - Обработка товара: A05 4/64 Black - 8600🇷🇺.
# [626/656] - Обработка товара: A06 4/64 Light Blue - 8700🇰🇿.
# [627/656] - Обработка товара: A16 4/128 Black - 14100🇦🇪.
# [628/656] - Обработка товара: A16 4/128 Green - 14100🇦🇪.
# [629/656] - Обработка товара: A16 4/128 Grey - 14100🇦🇪.
# [630/656] - Обработка товара: A16 8/256 Black - 17600🇦🇪.
# [631/656] - Обработка товара: A16 8/256 Green -17600🇦🇪.
# [632/656] - Обработка товара: A16 8/256 Grey - 17600🇦🇪.
# [633/656] - Обработка товара: A25 6/128 Blue Black 5G - 18700🇦🇪.
# [634/656] - Обработка товара: A35 8/128 Navy - 23500🇰🇿
# [635/656] - Обработка товара: A55 8/128 Navy - 29000🇰🇿
# [636/656] - Обработка товара: A55 8/128 Lilac - 29500🇰🇿
# [637/656] - Обработка товара: A55 8/128 Lemon- 29500🇵🇾
# [638/656] - Обработка товара: A55 8/256 Navy - 32000🇿🇦
# [639/656] - Обработка товара: Tab A9 X115 4/64 LTE Navy - 12200🇷🇺.
# [640/656] - Обработка товара: Tab A9 X115 4/64 LTE Graphite - 12200🇷🇺.
# [641/656] - Обработка товара: Galaxy Watch 6 R940 44mm Black 15500🇰🇿.
# [642/656] - Обработка товара: Galaxy Watch 6 Classic R950 43mm Silver 16500🇦🇪.
# [643/656] - Обработка товара: Galaxy Watch 6 Classic R960 47mm Silver 17500🇦🇪.
# [644/656] - Обработка товара: Redmi 12 8/256 Blue - 10700🇷🇺.
# [645/656] - Обработка товара: Redmi Note 11S 8/128 Blue - 15000🇪🇺
# [646/656] - Обработка товара: Note 14 8/256 Black 4G - 18800🇷🇺
# [647/656] - Обработка товара: Note 14 8/256 Green 4G - 18800🇷🇺
# [648/656] - Обработка товара: Realme Note 50 3/64 black - 5300🇷🇺.
# [649/656] - Обработка товара: Poco C75 6/128 Black - 9200🇷🇺.
# [650/656] - Обработка товара: Poco C75 6/128 Green - 9200🇷🇺.
# [651/656] - Обработка товара: Poco M6 6/128 Black - 12000🇷🇺.
# [652/656] - Обработка товара: Poco X6 Pro 12/512 Grey 5G - 29500🇪🇺
# [653/656] - Обработка товара: Honor X6A 6/128 Черный - 11500🇷🇺
# [654/656] - Обработка товара: Honor X6A 6/128 Голубой - 11500🇷🇺
# [655/656] - Обработка товара: Honor 200 Lite 8/256 Blue - 17800🇷🇺.
# [656/656] - Обработка товара: Honor 200 Lite 8/256 Green - 17800🇷🇺.

# %%
grouped = new_df.groupby("Товар в магазине")

excel_data = []

for product, group in grouped:
    row = {"Наше название": product}
    for i, (_, item) in enumerate(group.iterrows(), start=1):
        row[f"цена {i}"] = item["Цена"]
        row[f"поставщик {i}"] = item["Поставщик"]

    excel_data.append(row)

df_excel = pd.DataFrame(excel_data)

df_excel.to_excel("output_prices.xlsx", index=False)

print("✅ Excel-файл успешно создан: output_prices.xlsx")
# Out:
# ✅ Excel-файл успешно создан: output_prices.xlsx

# %%
excel_data_total = []

for product, group in grouped:
    row = {"Внешний код": group["Внешний код"].iloc[0], "Наше название": product}
    for i, (_, item) in enumerate(group.iterrows(), start=1):
        row[f"рекомендуемая {i}"] = item["Цена"] + item["Цена"] * 0.1
        row[f"цена {i}"] = item["Цена"]
        row[f"поставщик {i}"] = item["Поставщик"]

    excel_data_total.append(row)

all_keys = {key for row in excel_data_total for key in row}

fixed_order = ["Внешний код", "Наше название"] + sorted(
    [k for k in all_keys if k.startswith("рекомендуемая")]
)

supplier_price_pairs = [
    key
    for i in range(
        1,
        max(
            (int(k.split()[-1]) for k in all_keys if k.startswith("поставщик")),
            default=0,
        )
        + 1,
    )
    for key in (f"поставщик {i}", f"цена {i}")
    if key in all_keys
]
fixed_order += supplier_price_pairs

excel_data_total = [
    {key: row.get(key, None) for key in fixed_order} for row in excel_data_total
]
df_excel = pd.DataFrame(excel_data_total)
df_excel.to_excel("output_prices_total.xlsx", index=False)
print(
    "✅ Excel-файл с рассчетом рекомендуемой цены успешно создан: output_prices_total.xlsx"
)
# Out:
# ✅ Excel-файл с рассчетом рекомендуемой цены успешно создан: output_prices_total.xlsx
